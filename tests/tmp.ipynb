# %%
import enum

class Auth(enum.Enum):
    __token__ = "__token__"

# %%
dir(Auth)
# Out:
# ['__class__',
#  '__contains__',
#  '__doc__',
#  '__getitem__',
#  '__init_subclass__',
#  '__iter__',
#  '__len__',
#  '__members__',
#  '__module__',
#  '__name__',
#  '__qualname__']
